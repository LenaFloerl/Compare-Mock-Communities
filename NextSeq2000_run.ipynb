# %% [markdown]
# # Compare mock communities from the NextSeq2000 run
#
# These mock communities have been used as positive controls within the RxCS project (see analysis here: https://github.com/LenaFloerl/RxCS.git).
#
# These were already demultiplexed, denoised with dada2 and taxonomically classified with UNITE database (v9.0) and SILVA (99%, release 138, trained for the 16S  515F-806R (V4) region)

# %%
import qiime2 as q2
import qiime2.plugins.taxa.actions as taxa_actions
from qiime2 import Visualization, Metadata
from qiime2.plugins.taxa.methods import collapse
from qiime2.plugins.feature_table.methods import relative_frequency 
from biom import load_table
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches


# %matplotlib inline

# %% [markdown]
# # ITS

# %%
wd = '/home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/ITS-fwd'
# %cd $wd
# Out:
# /home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/ITS-fwd

# %%
metadata = '/home/lfloerl/RxCS/Metadata/ITS_metadata.tsv'
md = Metadata.load(metadata)

taxonomy = q2.Artifact.load('taxonomy.qza')

# %% [markdown]
# ### Get positive controls

# %%
# %%bash
#
# qiime feature-table filter-samples \
#   --i-table decontam-table.qza \
#   --m-metadata-file /home/lfloerl/RxCS/Metadata/ITS_metadata.tsv \
#   --p-where "[control]='pos_ctrl' AND [Sample_ID] IN ('DNA18-pos-1','DNA19-pos-1','DNA7-pos-1','DNA18-pos-2','DNA23-pos-1','DNA5-pos-1','DNA20-pos-1')" \
#   --o-filtered-table pos-ctrl-table.qza
# Out:
# Saved FeatureTable[Frequency] to: pos-ctrl-table.qza

# %%
table = q2.Artifact.load('pos-ctrl-table.qza')

# %% [markdown]
# ### Make a taxa barplot

# %%
taxa_bar_plots_viz, = taxa_actions.barplot(
    table=table,
    taxonomy=taxonomy,
    metadata=md
)
taxa_bar_plots_viz.save('pos-ctrl-taxa_barplot.qzv')
# Out:
# 'pos-ctrl-taxa_barplot.qzv'

# %%
Visualization.load('pos-ctrl-taxa_barplot.qzv')
# Out:
# <visualization: Visualization uuid: 3fafbeab-a14d-4979-8e03-98793b310636>

# %%
# collapse table at taxonomic level 7 (ASVs)
collapsed_table, = collapse(table=table,
                           taxonomy=taxonomy,
                           level=7)

# get the relative frequencies 
relative_freq_collapsed, = relative_frequency(table=collapsed_table)
relative_freq_collapsed.save('relative_freq_collapsed.qza')

# export 
# !qiime tools export --input-path relative_freq_collapsed.qza --output-path relative_freq_collapsed
# Out:
# Exported relative_freq_collapsed.qza as BIOMV210DirFmt to directory relative_freq_collapsed

# %%
# convert the biom table to a df
def biom_to_dataframe(biom_file):
    table = load_table(biom_file)
    df = pd.DataFrame(table.matrix_data.toarray(), 
                      index=table.ids(axis='observation'), 
                      columns=table.ids(axis='sample'))
    return df

df_ITS = biom_to_dataframe('relative_freq_collapsed/feature-table.biom')

# metadata
md_df = md.to_dataframe()

# %%
# rename the cols to the sample names 
column_mapping = md_df['Sample_ID'].to_dict()
df_ITS = pd_biom.rename(columns=column_mapping)

# %%
df_ITS.head()
# Out:
#                                                     DNA18-pos-1_noPNAs_0  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.235959
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...              0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...              0.000000
#
#                                                     DNA18-pos-1_mPNA_0.25  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.232901
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
#
#                                                     DNA18-pos-1_mPNA_0.5  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.235239
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...              0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...              0.000000
#
#                                                     DNA18-pos-1_mPNA_0.75  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.235016
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
#
#                                                     DNA18-pos-1_mPNA_1  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...            0.232221
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...            0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...            0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...            0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...            0.000000
#
#                                                     DNA18-pos-1_mPNA_1.25  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.229852
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
#
#                                                     DNA18-pos-1_pPNA_0.25  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.231567
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
#
#                                                     DNA18-pos-1_pPNA_0.5  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.225628
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...              0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...              0.000000
#
#                                                     DNA18-pos-1_pPNA_0.75  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.236547
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
#
#                                                     DNA18-pos-1_pPNA_1  ...  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...            0.238857  ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...            0.000000  ...
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...            0.000000  ...
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...            0.000000  ...
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...            0.000000  ...
#
#                                                     DNA18-pos-4  DNA21-pos-4  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.372263      0.08125
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.000000      0.00000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.000000      0.00000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...     0.000000      0.00000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...     0.000000      0.00000
#
#                                                     DNA21-pos-3  DNA22-pos-4  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.289517     0.142560
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.008319     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.046589     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...     0.000000     0.029136
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...     0.000000     0.000000
#
#                                                     DNA22-pos-3  DNA22-pos-2  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...      0.16939     0.237922
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.00000     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...      0.00000     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...      0.00000     0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...      0.00000     0.000000
#
#                                                     DNA23-pos-1  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.319685
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...     0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...     0.000000
#
#                                                     DNA18-pos-1_m+pPNA_0.75  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0.234261
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...                 0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                 0.000000
#
#                                                     DNA18-pos-1_m+pPNA_1  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.234518
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...              0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...              0.000000
#
#                                                     DNA18-pos-1_m+pPNA_1.25
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0.231764
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...                 0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                 0.000000
#
# [5 rows x 37 columns]

# %% [markdown]
# # 16S

# %%
wd = '/home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S'
# %cd $wd
# Out:
# /home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S

# %%
# !ls bac-dada2/dada-rep-seqs.qza
# Out:
# dada-rep-seqs-evaluate.qzv  dada-rep-seqs.qzv  dada-stats.qza  dada-table.qza
# dada-rep-seqs.qza	    dada-stats	       dada-stats.qzv  dada-table.qzv

# %%
metadata = '/home/lfloerl/RxCS/Metadata/16S_metadata.tsv'
md = Metadata.load(metadata)

taxonomy = q2.Artifact.load('taxonomy.qza')

# %%
# %%bash
#
# qiime feature-table filter-samples \
#   --i-table chloroplast_mitochondria_filtered_table.qza \
#   --m-metadata-file /home/lfloerl/RxCS/Metadata/16S_metadata.tsv \
#   --p-where "[control]='pos_ctrl' AND [Sample_ID] IN ('DNA18-pos-1','DNA19-pos-1','DNA7-pos-1','DNA18-pos-2','DNA23-pos-1','DNA5-pos-1','DNA20-pos-1')" \
#   --o-filtered-table pos-ctrl-table-ContamFiltered.qza
# Out:
# Saved FeatureTable[Frequency] to: pos-ctrl-table-ContamFiltered.qza

# %%
table = q2.Artifact.load('pos-ctrl-table-ContamFiltered.qza')

# %% [markdown]
# Taxa Barplot

# %%
taxa_bar_plots_viz, = taxa_actions.barplot(
    table=table,
    taxonomy=taxonomy,
    metadata=md
)
taxa_bar_plots_viz.save('pos-ctrl-taxa_barplot-ContamFiltered.qzv')
# Out:
# 'pos-ctrl-taxa_barplot-ContamFiltered.qzv'

# %%
Visualization.load('pos-ctrl-taxa_barplot-ContamFiltered.qzv')
# Out:
# <visualization: Visualization uuid: da4cc794-ed42-4401-b8ae-6978865a8110>

# %% [markdown]
# Export

# %%
# collapse table at taxonomic level 7 (ASVs)
collapsed_table, = collapse(table=table,
                           taxonomy=taxonomy,
                           level=7)

# get the relative frequencies 
relative_freq_collapsed, = relative_frequency(table=collapsed_table)
relative_freq_collapsed.save('relative_freq_collapsed.qza')

# export 
# !qiime tools export --input-path relative_freq_collapsed.qza --output-path relative_freq_collapsed
# Out:
# Exported relative_freq_collapsed.qza as BIOMV210DirFmt to directory relative_freq_collapsed

# %%
# convert the biom table to a df
def biom_to_dataframe(biom_file):
    table = load_table(biom_file)
    df = pd.DataFrame(table.matrix_data.toarray(), 
                      index=table.ids(axis='observation'), 
                      columns=table.ids(axis='sample'))
    return df

df_16S = biom_to_dataframe('relative_freq_collapsed/feature-table.biom')

# metadata
md_df = md.to_dataframe()

# %%
# rename the cols to the sample names 
column_mapping = md_df['Sample_ID'].to_dict()
df_16S = pd_biom.rename(columns=column_mapping)

# %%
df_16S.head()
# Out:
#                                                     DNA18-pos-1_noPNAs_0  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.235959
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...              0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...              0.000000
#
#                                                     DNA18-pos-1_mPNA_0.25  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.232901
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
#
#                                                     DNA18-pos-1_mPNA_0.5  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.235239
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...              0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...              0.000000
#
#                                                     DNA18-pos-1_mPNA_0.75  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.235016
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
#
#                                                     DNA18-pos-1_mPNA_1  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...            0.232221
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...            0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...            0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...            0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...            0.000000
#
#                                                     DNA18-pos-1_mPNA_1.25  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.229852
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
#
#                                                     DNA18-pos-1_pPNA_0.25  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.231567
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
#
#                                                     DNA18-pos-1_pPNA_0.5  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.225628
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...              0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...              0.000000
#
#                                                     DNA18-pos-1_pPNA_0.75  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.236547
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
#
#                                                     DNA18-pos-1_pPNA_1  ...  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...            0.238857  ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...            0.000000  ...
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...            0.000000  ...
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...            0.000000  ...
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...            0.000000  ...
#
#                                                     DNA18-pos-4  DNA21-pos-4  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.372263      0.08125
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.000000      0.00000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.000000      0.00000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...     0.000000      0.00000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...     0.000000      0.00000
#
#                                                     DNA21-pos-3  DNA22-pos-4  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.289517     0.142560
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.008319     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.046589     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...     0.000000     0.029136
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...     0.000000     0.000000
#
#                                                     DNA22-pos-3  DNA22-pos-2  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...      0.16939     0.237922
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.00000     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...      0.00000     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...      0.00000     0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...      0.00000     0.000000
#
#                                                     DNA23-pos-1  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.319685
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...     0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...     0.000000
#
#                                                     DNA18-pos-1_m+pPNA_0.75  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0.234261
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...                 0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                 0.000000
#
#                                                     DNA18-pos-1_m+pPNA_1  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.234518
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...              0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...              0.000000
#
#                                                     DNA18-pos-1_m+pPNA_1.25
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0.231764
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...                 0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                 0.000000
#
# [5 rows x 37 columns]

# %% [markdown]
# # Merge!

# %%
df_ITS.shape
# Out:
# (225, 37)

# %%
df_16S.shape
# Out:
# (225, 37)

# %%
df_combined = pd.concat([df_ITS, df_16S], axis=0)
df_combined
# Out:
#                                                     DNA18-pos-1_noPNAs_0  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.235959
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...              0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...              0.000000
# ...                                                                  ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...              0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...              0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
#
#                                                     DNA18-pos-1_mPNA_0.25  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.232901
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
# ...                                                                   ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...               0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...               0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
#
#                                                     DNA18-pos-1_mPNA_0.5  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.235239
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...              0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...              0.000000
# ...                                                                  ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...              0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...              0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
#
#                                                     DNA18-pos-1_mPNA_0.75  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.235016
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
# ...                                                                   ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...               0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...               0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
#
#                                                     DNA18-pos-1_mPNA_1  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...            0.232221
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...            0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...            0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...            0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...            0.000000
# ...                                                                ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...            0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...            0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...            0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...            0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...            0.000000
#
#                                                     DNA18-pos-1_mPNA_1.25  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.229852
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
# ...                                                                   ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...               0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...               0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
#
#                                                     DNA18-pos-1_pPNA_0.25  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.231567
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
# ...                                                                   ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...               0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...               0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000020
#
#                                                     DNA18-pos-1_pPNA_0.5  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.225628
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...              0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...              0.000000
# ...                                                                  ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...              0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...              0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
#
#                                                     DNA18-pos-1_pPNA_0.75  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.236547
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...               0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               0.000000
# ...                                                                   ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...               0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...               0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...               0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...               0.000000
#
#                                                     DNA18-pos-1_pPNA_1  ...  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...            0.238857  ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...            0.000000  ...
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...            0.000000  ...
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...            0.000000  ...
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...            0.000000  ...
# ...                                                                ...  ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...            0.000000  ...
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...            0.000000  ...
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...            0.000000  ...
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...            0.000000  ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...            0.000000  ...
#
#                                                     DNA18-pos-4  DNA21-pos-4  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.372263      0.08125
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.000000      0.00000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.000000      0.00000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...     0.000000      0.00000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...     0.000000      0.00000
# ...                                                         ...          ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.000000      0.00000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...     0.000000      0.00000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...     0.000000      0.00000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...     0.000000      0.00000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.000000      0.00000
#
#                                                     DNA21-pos-3  DNA22-pos-4  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.289517     0.142560
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.008319     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.046589     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...     0.000000     0.029136
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...     0.000000     0.000000
# ...                                                         ...          ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.000000     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...     0.056572     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...     0.000000     0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...     0.000000     0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.023295     0.000000
#
#                                                     DNA22-pos-3  DNA22-pos-2  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...      0.16939     0.237922
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.00000     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...      0.00000     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...      0.00000     0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...      0.00000     0.000000
# ...                                                         ...          ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.00000     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...      0.00000     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...      0.00000     0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...      0.00000     0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.00000     0.000000
#
#                                                     DNA23-pos-1  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.319685
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...     0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...     0.000000
# ...                                                         ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...     0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...     0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...     0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...     0.000000
#
#                                                     DNA18-pos-1_m+pPNA_0.75  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0.234261
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...                 0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                 0.000000
# ...                                                                     ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...                 0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...                 0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...                 0.000000
#
#                                                     DNA18-pos-1_m+pPNA_1  \
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.234518
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...              0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...              0.000000
# ...                                                                  ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...              0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...              0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...              0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...              0.000000
#
#                                                     DNA18-pos-1_m+pPNA_1.25
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0.231764
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Paeniba...                 0.000000
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                 0.000000
# ...                                                                     ...
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...                 0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Alicycl...                 0.000000
# d__Bacteria;p__Chloroflexi;c__KD4-96;o__KD4-96;...                 0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...                 0.000000
#
# [450 rows x 37 columns]
